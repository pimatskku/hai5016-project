# %%
import pandas as pd

# %%
# Load the JSONL file into a DataFrame
menus_df = pd.read_json(r"results\menus-2026-04-23.jsonl", lines=True)

# Show basic info to confirm it loaded correctly
print(menus_df.shape)
menus_df.head()
# Out:
# (60, 8)
#            scrape_date                                                url  \
# 0  2026-04-23 17:50:57  https://www.skku.edu/skku/campus/support/welfa...
# 1  2026-04-23 17:50:57  https://www.skku.edu/skku/campus/support/welfa...
# 2  2026-04-23 17:50:57  https://www.skku.edu/skku/campus/support/welfa...
# 3  2026-04-23 17:50:57  https://www.skku.edu/skku/campus/support/welfa...
# 4  2026-04-23 17:50:57  https://www.skku.edu/skku/campus/support/welfa...
#
#     menu_date meal_type meal_name  price_krw university restaurant_name
# 0  2026-04-20     lunch      부대찌개       9000       SKKU           패컬티식당
# 1  2026-04-20     lunch   언양식너비아니       9000       SKKU           패컬티식당
# 2  2026-04-20     lunch     계란장조림       9000       SKKU           패컬티식당
# 3  2026-04-20     lunch  꽈리고추멸치볶음       9000       SKKU           패컬티식당
# 4  2026-04-20     lunch  진미채고추장무침       9000       SKKU           패컬티식당
